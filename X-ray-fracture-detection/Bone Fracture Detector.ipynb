# %%
import cv2

# %%
import torch
import numpy as np

# %%
import pathlib
temp = pathlib.PosixPath
pathlib.PosixPath = pathlib.WindowsPath

# %%
model = torch.hub.load("ultralytics/yolov5","custom", path = r"C:\Users\Anfal\Downloads\Bone fractureModelTrain\yolov5\runs\train\exp\weights\best.pt", force_reload = True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\Anfal/.cache\torch\hub\master.zip
# YOLOv5  2025-8-28 Python-3.11.3 torch-2.8.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
cap = cv2.VideoCapture(r"C:\Users\Anfal\Downloads\video5872849245878362165.mp4")

while True:
    ret, frame = cap.read()
    if not ret:
        break


    frame_resized = cv2.resize(frame, (480, 480))


    results = model(frame_resized)

  
    cv2.imshow("Fracture Detection", np.squeeze(results.render()))


    if cv2.waitKey(1) == ord("q"):
        break

# تحرير الكاميرا وإغلاق النوافذ
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Anfal/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\Anfal/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\Anfal/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# C:\Users\Anfal/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# ...
